# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'getTotalX' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER_ARRAY a
#  2. INTEGER_ARRAY b
#

first_multiple_input = input().rstrip().split()

n = int(first_multiple_input[0])

m = int(first_multiple_input[1])

arr = list(map(int, input().rstrip().split()))

brr = list(map(int, input().rstrip().split()))

lcm = max(arr)
    
lcm_list = []
    
while (lcm <= min(brr)):
    for i in range(len(arr)):
        if lcm%arr[i] != 0:
            break
        if lcm%arr[i] == 0:
            if i == len(arr)-1:
                lcm_list.append(lcm)
    lcm +=1
lcm_list
        

final_lcm_list = []

for i in lcm_list:
    for j in range(len(brr)):
        if brr[j]%i != 0:
            break
        if brr[j]%i == 0:
            if j == len(brr)-1:
                final_lcm_list.append(i)
print(len(final_lcm_list))
# Out:
# 2 3
# 2 4
# 16 32 96
# 3
