# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the staircase function below.
def staircase(n):
    
    s = n-1
    d = 1
    for i in range(n):
        
        for j in range(s):
            print(' ', end='')
        s -= 1
        
        
        for k in range(d):
            print('#', end='')
        print()
        d = n-s
            

if __name__ == '__main__':
    n = int(input())

    staircase(n)
# Out:
# 6
#      #
#     ##
#    ###
#   ####
#  #####
# ######
