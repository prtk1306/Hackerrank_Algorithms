# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

ar_count = int(input())
ar = list(map(int, input().rstrip().split()))

m = max(s)
c = 0

for i in ar:
    if i == m:
        c+=1
print(c)
# Out:
# 4
# 3 2 1 3
# 2
